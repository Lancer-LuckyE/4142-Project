# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sqlalchemy import create_engine

engine = create_engine('postgresql://hli165:E456tutc57@www.eecs.uottawa.ca:15432/group_21')

sql = 'SELECT CF.crime_key, CF.location_key, crime_category, crime_type, neighbourhood, address \
      FROM crime_data_mart.crimefact as CF, crime_data_mart.crime as C, crime_data_mart.location as L \
      WHERE CF.crime_key = C.crime_key and CF.location_key = L.location_key and address != \'NOT APPLICABLE\' and neighbourhood != \'None\' \
      LIMIT 100000'

df = pd.read_sql(sql, engine)

# %%
crimeNeighbour_df = df.groupby(['crime_type', 'neighbourhood']).size().reset_index(name='counts')
cirme_dict = df['crime_type'].value_counts().to_dict()
crimeNeighbour_df['total'] = crimeNeighbour_df['crime_type'].map(cirme_dict)
crimeNeighbour_df['freq'] = crimeNeighbour_df['counts'] / crimeNeighbour_df['total']
df = df.join(crimeNeighbour_df.set_index(['crime_type', 'neighbourhood']), on=['crime_type', 'neighbourhood'])
df = df.loc[df['crime_type']=='traffic-accident-hit-and-run']
df = df.sort_values('neighbourhood', ascending=False)
df= df.drop_duplicates(subset ="neighbourhood", keep = 'first')

# %%
print(df)
# Out:
#        crime_key  location_key    crime_category  \
# 40280      70829         31824  traffic-accident
# 44483     219263         85628  traffic-accident
# 35452     129045          2280  traffic-accident
# 7101      335133        114861  traffic-accident
# 63890     243887          4706  traffic-accident
# 79274     239383         33145  traffic-accident
# 35695     165317         69783  traffic-accident
# 29601     243061        112802  traffic-accident
# 20428     151303           283  traffic-accident
# 83065        692         90815  traffic-accident
# 91766      55920          4681  traffic-accident
# 82286     126214          7861  traffic-accident
# 83772     379764          4874  traffic-accident
# 26159     242171         34181  traffic-accident
# 51930      53236          1308  traffic-accident
# 45030     320745          5391  traffic-accident
# 81888      63014         20401  traffic-accident
# 92167     234283          3109  traffic-accident
# 47907     341695          7355  traffic-accident
# 66017      65507         29423  traffic-accident
# 95024      61685          1741  traffic-accident
# 63460     132854         56261  traffic-accident
# 55699     221312         64163  traffic-accident
# 91649       9998          2664  traffic-accident
# 8514       24197         14553  traffic-accident
# 47849      25274          4936  traffic-accident
# 18242     287156         19521  traffic-accident
# 70758     347968        118208  traffic-accident
# 4202      386821           246  traffic-accident
# 68639      12231          8282  traffic-accident
# ...          ...           ...               ...
# 3262       22053          3246  traffic-accident
# 40692     135721          2146  traffic-accident
# 61648     244007         33710  traffic-accident
# 88543      23916         14410  traffic-accident
# 25388      27941         17422  traffic-accident
# 21081     301014           565  traffic-accident
# 49145      36390         20255  traffic-accident
# 56156     297306         46483  traffic-accident
# 7224      358281         38651  traffic-accident
# 62685      38251         21092  traffic-accident
# 74574     371503        116748  traffic-accident
# 17299     139332         61693  traffic-accident
# 8468       13175          8833  traffic-accident
# 44429     209871         52728  traffic-accident
# 13210       1027           910  traffic-accident
# 24973      22726         13841  traffic-accident
# 52456     250239          3291  traffic-accident
# 26679     104727         12066  traffic-accident
# 95254      96672         46282  traffic-accident
# 23055      99060           887  traffic-accident
# 6098      156449         67016  traffic-accident
# 2073       43558           999  traffic-accident
# 91211     133004         59459  traffic-accident
# 96820     155459          7953  traffic-accident
# 78444     101106         20316  traffic-accident
# 34676       2063          1717  traffic-accident
# 34734      13399          8957  traffic-accident
# 70698     332181          1030  traffic-accident
# 910       383098          1404  traffic-accident
# 85882     147502         64169  traffic-accident
#
#                          crime_type               neighbourhood  \
# 40280  traffic-accident-hit-and-run                     windsor
# 44483  traffic-accident-hit-and-run                    whittier
# 35452  traffic-accident-hit-and-run                    westwood
# 7101   traffic-accident-hit-and-run               west-highland
# 63890  traffic-accident-hit-and-run                 west-colfax
# 79274  traffic-accident-hit-and-run                   wellshire
# 35695  traffic-accident-hit-and-run    washington-virginia-vale
# 29601  traffic-accident-hit-and-run        washington-park-west
# 20428  traffic-accident-hit-and-run             washington-park
# 83065  traffic-accident-hit-and-run            virginia-village
# 91766  traffic-accident-hit-and-run                  villa-park
# 82286  traffic-accident-hit-and-run                    valverde
# 83772  traffic-accident-hit-and-run             university-park
# 26159  traffic-accident-hit-and-run            university-hills
# 51930  traffic-accident-hit-and-run                  university
# 45030  traffic-accident-hit-and-run               union-station
# 81888  traffic-accident-hit-and-run                   sunnyside
# 92167  traffic-accident-hit-and-run                  sun-valley
# 47907  traffic-accident-hit-and-run                   stapleton
# 66017  traffic-accident-hit-and-run                       speer
# 95024  traffic-accident-hit-and-run              southmoor-park
# 63460  traffic-accident-hit-and-run             south-park-hill
# 55699  traffic-accident-hit-and-run                  sloan-lake
# 91649  traffic-accident-hit-and-run                     skyland
# 8514   traffic-accident-hit-and-run                   ruby-hill
# 47849  traffic-accident-hit-and-run                    rosedale
# 18242  traffic-accident-hit-and-run                       regis
# 70758  traffic-accident-hit-and-run                  platt-park
# 4202   traffic-accident-hit-and-run                    overland
# 68639  traffic-accident-hit-and-run         northeast-park-hill
# ...                             ...                         ...
# 3262   traffic-accident-hit-and-run                   goldsmith
# 40692  traffic-accident-hit-and-run                  globeville
# 61648  traffic-accident-hit-and-run  gateway-green-valley-ranch
# 88543  traffic-accident-hit-and-run                  fort-logan
# 25388  traffic-accident-hit-and-run                 five-points
# 21081  traffic-accident-hit-and-run              elyria-swansea
# 49145  traffic-accident-hit-and-run                 east-colfax
# 56156  traffic-accident-hit-and-run                         dia
# 7224   traffic-accident-hit-and-run                country-club
# 62685  traffic-accident-hit-and-run                cory-merrill
# 74574  traffic-accident-hit-and-run               congress-park
# 17299  traffic-accident-hit-and-run   college-view-south-platte
# 8468   traffic-accident-hit-and-run                        cole
# 44429  traffic-accident-hit-and-run                     clayton
# 13210  traffic-accident-hit-and-run                civic-center
# 24973  traffic-accident-hit-and-run              city-park-west
# 52456  traffic-accident-hit-and-run                   city-park
# 26679  traffic-accident-hit-and-run                cherry-creek
# 95254  traffic-accident-hit-and-run               cheesman-park
# 23055  traffic-accident-hit-and-run                chaffee-park
# 6098   traffic-accident-hit-and-run                         cbd
# 2073   traffic-accident-hit-and-run                capitol-hill
# 91211  traffic-accident-hit-and-run                    berkeley
# 96820  traffic-accident-hit-and-run                     belcaro
# 78444  traffic-accident-hit-and-run                 bear-valley
# 34676  traffic-accident-hit-and-run                 barnum-west
# 34734  traffic-accident-hit-and-run                      barnum
# 70698  traffic-accident-hit-and-run                       baker
# 910    traffic-accident-hit-and-run                     auraria
# 85882  traffic-accident-hit-and-run                 athmar-park
#
#                                   address  counts  total      freq
# 40280                  8680 E ALAMEDA AVE      29   5176  0.005603
# 44483             2300 BLOCK N DOWNING ST      15   5176  0.002898
# 35452          4800 BLOCK W TENNESSEE AVE     136   5176  0.026275
# 7101             3500 BLK N SHERIDAN BLVD      65   5176  0.012558
# 63890        W COLFAX AVE / N LOWELL BLVD      60   5176  0.011592
# 79274               2400 BLOCK E YALE AVE       6   5176  0.001159
# 35695           E DAKOTA AVE / S HOLLY ST      76   5176  0.014683
# 29601            1100 BLOCK S CLARKSON ST      46   5176  0.008887
# 20428       I25 HWYNB / S UNIVERSITY BLVD      27   5176  0.005216
# 83065                 1700 BLOCK S ELM ST      55   5176  0.010626
# 91766                      645 N WOLFF ST      79   5176  0.015263
# 82286            S TEJON ST / W CEDAR AVE      31   5176  0.005989
# 83772       S COLORADO BLVD / E EVANS AVE      36   5176  0.006955
# 26159              2200 BLOCK S ALBION ST      45   5176  0.008694
# 51930       I25 HWYSB / S UNIVERSITY BLVD      54   5176  0.010433
# 45030               14TH ST / LAWRENCE ST     124   5176  0.023957
# 81888                     1311 W 46TH AVE      78   5176  0.015070
# 92167           W 10TH AVE / N DECATUR ST      32   5176  0.006182
# 47907              8340 E NORTHFIELD BLVD     258   5176  0.049845
# 66017                100 BLOCK S LOGAN ST     113   5176  0.021832
# 95024           E HAMPDEN AVE / I25 HWYSB      25   5176  0.004830
# 63460          N KRAMERIA ST / E 17TH AVE      35   5176  0.006762
# 55699            W 24TH AVE / N IRVING ST      31   5176  0.005989
# 91649              E MLK BLVD / N YORK ST      26   5176  0.005023
# 8514                    1650 S WYANDOT ST      63   5176  0.012172
# 47849          E EVANS AVE / S DOWNING ST      19   5176  0.003671
# 18242         N FEDERAL BLVD / W 49TH AVE      27   5176  0.005216
# 70758                1500 BLK S CORONA ST      35   5176  0.006762
# 4202        S SANTA FE DR / W FLORIDA AVE      79   5176  0.015263
# 68639               I70 HWYEB / QUEBEC ST     100   5176  0.019320
# ...                                   ...     ...    ...       ...
# 3262                     6875 E ILIFF AVE      54   5176  0.010433
# 40692               I25 HWYSB / I70 HWYWB     104   5176  0.020093
# 61648             E 42ND AVE / N ANDES CT     103   5176  0.019900
# 88543  W HAMPDEN S FRTG / S SHERIDAN BLVD      17   5176  0.003284
# 25388                 32ND ST / WALNUT ST     201   5176  0.038833
# 21081                     3200 E 45TH AVE     103   5176  0.019900
# 49145          8200 BLOCK E MONTVIEW BLVD      74   5176  0.014297
# 56156                      8214 PENA BLVD      72   5176  0.013910
# 7224                N YORK ST / E 6TH AVE      24   5176  0.004637
# 62685           1100 BLOCK S ELIZABETH ST      34   5176  0.006569
# 74574             1400 BLOCK N MADISON ST      86   5176  0.016615
# 17299                 2700 BLK W YALE AVE      51   5176  0.009853
# 8468               N YORK ST / E 37TH AVE      28   5176  0.005410
# 44429                3900 BLOCK N YORK ST      25   5176  0.004830
# 13210                400 BLOCK W 12TH AVE      87   5176  0.016808
# 24973            N GILPIN ST / E 16TH AVE      58   5176  0.011206
# 52456                   2341 E COLFAX AVE      27   5176  0.005216
# 26679          E 3RD AVE / N MILWAUKEE ST      90   5176  0.017388
# 95254               1300 BLK E COLFAX AVE      68   5176  0.013138
# 23055                 5090 N FEDERAL BLVD      31   5176  0.005989
# 6098                          300 15TH ST     127   5176  0.024536
# 2073            E COLFAX AVE / N PEARL ST     185   5176  0.035742
# 91211               4500 BLOCK N MEADE ST      69   5176  0.013331
# 96820     E ALAMEDA AVE / S COLORADO BLVD      34   5176  0.006569
# 78444     W COLUMBIA PL / S SHERIDAN BLVD      25   5176  0.004830
# 34676            W 5TH AVE / N RALEIGH ST      26   5176  0.005023
# 34734                       125 N KNOX CT      60   5176  0.011592
# 70698               I25 HWYNB / W 6TH AVE     205   5176  0.039606
# 910              I25 HWYNB / AURARIA PKWY      63   5176  0.012172
# 85882          2800 BLOCK W TENNESSEE AVE      72   5176  0.013910
#
# [78 rows x 9 columns]

# %%
from sklearn.cluster import KMeans 
import matplotlib.pyplot as plt
SSE = []  # 存放每次结果的误差平方和
for k in range(1,9):
    estimator = KMeans(n_clusters=k)  # 构造聚类器
    estimator.fit(df[['location_key','freq']])
    SSE.append(estimator.inertia_) # estimator.inertia_获取聚类准则的总和
X = range(1,9)
plt.xlabel('k')
plt.ylabel('SSE')
plt.plot(X,SSE,'o-')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

clustering = AgglomerativeClustering(linkage='ward', n_clusters=3)

clustering.fit(df[['location_key','freq']])
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=3,
#                         pooling_func='deprecated')

# %%
import matplotlib.pyplot as plt


plt.figure()
d0 = df[clustering.labels_ == 0]

plt.plot(d0['location_key'], d0['freq'], 'r.')
d1 = df[clustering.labels_ == 1]

plt.plot(d1['location_key'], d1['freq'], 'go')

plt.show()


print("The neigbourhood in first label tag are:"+ str(d0['neighbourhood'].unique()[:-1]))
print("The neigbourhood in second label tag are:")
print(d1['neighbourhood'].unique()[:-1])
# Out:
# The neigbourhood in first label tag are:['windsor' 'wellshire' 'washington-virginia-vale' 'university-hills'
#  'sunnyside' 'speer' 'south-park-hill' 'sloan-lake' 'regis'
#  'north-park-hill' 'montclair' 'montbello' 'mar-lee' 'kennedy'
#  'jefferson-park' 'indian-creek' 'hilltop' 'harvey-park-south'
#  'harvey-park' 'hampden-south' 'hale' 'gateway-green-valley-ranch'
#  'five-points' 'east-colfax' 'dia' 'country-club' 'cory-merrill'
#  'college-view-south-platte' 'clayton' 'cheesman-park' 'cbd' 'berkeley'
#  'bear-valley']
# The neigbourhood in second label tag are:
# ['whittier' 'west-highland' 'washington-park-west' 'virginia-village'
#  'platt-park' 'lowry-field' 'lincoln-park']
